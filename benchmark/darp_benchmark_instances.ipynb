# %% [markdown]
# # DARP Benchmark Instances

# %% [markdown]
# Este notebook tem como objetivo estudar e analisar os dados extraidos do [Scopus](https://www.scopus.com/) sobre os três artigos que primeiramente propuseram as instâncias de benchmark para o DARP e que são mencionadas por Ho et al. (2018).

# %%
import pandas as pd
import re
import matplotlib.pyplot as plt
plt.style.use('dark_background')
% matplotlib inline

# %%
# Importar dados dos arquivos, e concatena-los

arquivos = ["darp/cordeau&laporte(2003)/cite_cordeau&laporte(2003).csv",
            "darp/cordeau(2006)/cite_cordeau(2006).csv",
            "darp/ropke_etal(2007)/cite_ropke_etal(2007).csv",
            "darp/ropke&cordeau(2009)/cite_ropke&cordeau(2009).csv"]

colunas_relevantes = ['Authors', 'Title', 'Year', 'Source title', 'Author Keywords', 'Index Keywords',
                      'Abstract', 'Cited by', 'Document Type', 'Language of Original Document']

def importar_csv_com_fonte(arquivo):
    df = (pd.read_csv(arquivo, usecols=colunas_relevantes)
            .assign(CiteArticle = re.search("/cite_(.*).csv", arquivo).group(1))
    )
    return (df)


dados = (pd.concat(map(importar_csv_com_fonte, arquivos),)
           .reset_index(drop=True)
)

# %%
# Verificar se todos os dados foram corretamente importados
dados.groupby("CiteArticle")["Title"].count()
# Out:
# CiteArticle
# cordeau&laporte(2003)    265
# cordeau(2006)            192
# ropke&cordeau(2009)      121
# ropke_etal(2007)         125
# Name: Title, dtype: int64

# %%
# Deletar dados duplicados
dados.drop_duplicates(subset=colunas_relevantes, inplace=True)

# %% [markdown]
# Com os dados importados, procura-se filtrar os artigos que tratem de problemas dinâmicos. Para isso, será selecionado todo o artigo que mencionar a palavra "Dynamic" no título, resumo ou lista de palavras-chave

# %%
dados_dinamicos = (dados.assign(AllKeywords = lambda x: x["Author Keywords"].str.cat(x["Index Keywords"], na_rep=""))
                        .assign(DynamicTitle = lambda x: x.Title.str.contains("Dynamic"),
                                DynamicKeywords = lambda x: x.AllKeywords.str.contains("Dynamic"),
                                DynamicAbstract = lambda x: x.Abstract.str.contains("Dynamic"))
                        .assign(DynamicAny = lambda x: (x.DynamicTitle | x.DynamicKeywords | x.DynamicAbstract))                        
)
dados_dinamicos = dados_dinamicos.loc[dados_dinamicos["DynamicAny"] == True,:]

# %%
dados_dinamicos.shape
# Out:
# (56, 16)

# %%
dados_dinamicos.groupby("Document Type")["Title"].count()
# Out:
# Document Type
# Article             39
# Book Chapter         1
# Conference Paper    13
# Review               2
# Short Survey         1
# Name: Title, dtype: int64

# %% [markdown]
# Com esse filtro aplicado, sobram 56 itens, dos quais 39 são artigos de revista, 13 são artigos de conferência. Lendo o resumo do livro, das revisões e da pesquisa, coclui-se que estes não são de interesse para análise, já quenão apresentam experimentos computacionais.

# %%
artigos_dinamicos = dados_dinamicos.loc[dados_dinamicos["Document Type"].isin(["Article", "Conference Paper"])]

# %%
artigos_dinamicos.groupby("Language of Original Document")["Title"].count()
# Out:
# Language of Original Document
# English    51
# French      1
# Name: Title, dtype: int64

# %% [markdown]
# Lendo o resumo dos artigos restantes, foi possível determinar quais tratam de DARP, ou PDPTW dinâmicos e quais executam experimentos computacionais. Todos os artigos que não cumprem essas exigências foram deletados da análise.

# %%
indices_para_dropar = [53, 58, 62, 63, 64, 72, 73, 78, 93, 118, 128, 133, 140, 144, 148, 160, 185, 192,
                       205, 226, 238, 281, 313, 319, 327, 358, 387, 407, 417, 459, 522, 562, 567, 593,
                       597, 615, 636, 644, 700]

indices_para_dropar.sort()

# %%
artigos_realmente_dinamicos = artigos_dinamicos.drop(labels=indices_para_dropar)

# %% [markdown]
# Através da leitura das seções dos artigos que denotam as características dos experimentos, observa-se quais as instâncias usadas. A informação observada está inserida na coluna `"Instances"` no `DataFrame` `artigos_dinamicos`.

# %%
artigos_instancias = artigos_realmente_dinamicos.assign(Instance = False)
artigos_instancias.loc[artigos_instancias["Title"].str.contains("Double-horizon based heuristics for"),
                      "Instance"] = "Self-made, Realistic"
artigos_instancias.loc[artigos_instancias["Title"].str.contains("Waiting strategies for the dynamic pickup and"),
                      "Instance"] = "Self-made, Realistic"
artigos_instancias.loc[artigos_instancias["Title"].str.contains("Dynamic transportation of patients in hospitals"),
                      "Instance"] = "Self-made, Real"
artigos_instancias.loc[artigos_instancias["Title"].str.contains("Metaheuristics for the dynamic stochastic di"),
                      "Instance"] = "Self-made, Realistic, Dynamization"
artigos_instancias.loc[artigos_instancias["Title"].str.contains("On dynamic pickup and delivery vehicle"),
                      "Instance"] = "Self-made, Realistic"
artigos_instancias.loc[artigos_instancias["Title"].str.contains("Large scale realtime ridesharing with"),
                      "Instance"] = "Self-made, Real"
artigos_instancias.loc[artigos_instancias["Title"].str.contains("A tabu search heuristic for the dynamic "),
                      "Instance"] = "Self-made, Real, Realistic"
artigos_instancias.loc[artigos_instancias["Title"].str.contains("A hybrid tabu search and constraint programming algorithm"),
                      "Instance"] = "Cordeau(2006), Dynamization"
artigos_instancias.loc[artigos_instancias["Title"].str.contains("Checking the feasibility of dial-a-ride instances using c"),
                      "Instance"] = "Cordeau(2006), Dynamization"
artigos_instancias.loc[artigos_instancias["Title"].str.contains("On dynamic demand responsive transport services with degree"),
                      "Instance"] = "Self-made"
artigos_instancias.loc[artigos_instancias["Title"].str.contains("Waiting strategies for the dynamic dial-a-ride problem"),
                      "Instance"] = "Self-made"
artigos_instancias.loc[artigos_instancias["Title"].str.contains("Maximizing the number of served requests in an online shared"),
                      "Instance"] = "Self-made"
artigos_instancias.loc[artigos_instancias["Title"].str.contains("Determination of robust solutions for the dynamic dial-a-ri"),
                      "Instance"] = "Self-made"

# %%
artigos_instancias.shape[0]
# Out:
# 13

# %%
artigos_instancias.sort_values("Cited by", ascending=False)
# Out:
#                                                Authors  \
# 264     Mitrović-Minić S., Krishnamurti R., Laporte G.
# 263                      Mitrović-Minić S., Laporte G.
# 196         Beaudry A., Laporte G., Melo T., Nickel S.
# 164               Schilde M., Doerner K.F., Hartl R.F.
# 248                                 Fabri A., Recht P.
# 351            Huang Y., Bastani F., Jin R., Wang X.S.
# 168    Kergosien Y., Lenté C., Piton D., Billaut J.-C.
# 153            Berbeglia G., Cordeau J.-F., Laporte G.
# 181            Berbeglia G., Pesant G., Rousseau L.-M.
# 103                     Wong K.I., Han A.F., Yuen C.W.
# 208                     Yuen C.W., Wong K.I., Han A.F.
# 34         Vallée S., Oulamara A., Cherif-Khettaf W.R.
# 82   Chassaing M., Giboulot V., Lacomme P., Quillio...
#
#                                                  Title  Year  \
# 264  Double-horizon based heuristics for the dynami...  2004
# 263  Waiting strategies for the dynamic pickup and ...  2004
# 196    Dynamic transportation of patients in hospitals  2010
# 164  Metaheuristics for the dynamic stochastic dial...  2011
# 248  On dynamic pickup and delivery vehicle routing...  2006
# 351  Large scale realtime ridesharing with service ...  2014
# 168  A tabu search heuristic for the dynamic transp...  2011
# 153  A hybrid tabu search and constraint programmin...  2012
# 181  Checking the feasibility of dial-a-ride instan...  2011
# 103  On dynamic demand responsive transport service...  2014
# 208  Waiting strategies for the dynamic dial-a-ride...  2009
# 34   Maximizing the number of served requests in an...  2017
# 82   Determination of robust solutions for the dyna...  2015
#
#                                           Source title  Cited by  \
# 264     Transportation Research Part B: Methodological     142.0
# 263     Transportation Research Part B: Methodological     109.0
# 196                                        OR Spectrum      72.0
# 164                  Computers and Operations Research      48.0
# 248     Transportation Research Part B: Methodological      46.0
# 351                  Proceedings of the VLDB Endowment      42.0
# 168           European Journal of Operational Research      28.0
# 153                       INFORMS Journal on Computing      26.0
# 181                             Transportation Science      16.0
# 103              Transportmetrica A: Transport Science       4.0
# 208  International Journal of Environment and Susta...       2.0
# 34   Lecture Notes in Computer Science (including s...       NaN
# 82   Proceedings - CIE 45: 2015 International Confe...       NaN
#
#                                               Abstract  \
# 264  The dynamic Pickup and Delivery Problem with T...
# 263  The dynamic pickup and delivery problem with t...
# 196  This study analyzes and solves a patient trans...
# 164  The problem of transporting patients or elderl...
# 248  In 2001, Caramia and his coauthors introduced ...
# 351  Urban traffic gridlock is a familiar scene. At...
# 168  The problem studied in this paper stems from a...
# 153  This paper introduces a hybrid algorithm for t...
# 181  In the dial-a-ride problem (DARP), a fleet of ...
# 103  The operation of a demand responsive transport...
# 208  The dial-a-ride service is a form of demand re...
# 34   The Dial-a-Ride Problem (DARP) consists in ser...
# 82   This paper deals with a dynamic dial-a-ride pr...
#
#                                        Author Keywords  \
# 264  Dynamic pickup and delivery problem with time ...
# 263  Dynamic pickup and delivery problem with time ...
# 196  Dial-a-ride; Dynamic mode; In-house hospital t...
# 164  Dial-a-ride problem; Dynamic problem; Metaheur...
# 248  Dial-a-ride; Dynamic; Pickup and delivery; Tim...
# 351                                                NaN
# 168  Health care; Real-time; Tabu search; Transport...
# 153  Constraint programming; Dial-a-ride problem; D...
# 181  Algorithms; Constraint programming; Dial-A-Rid...
# 103  degree of dynamism; demand responsive transpor...
# 208  DARP; Degree of dynamism; Dial-a-ride problem;...
# 34   Computational experiments; Dynamic DARP; Inser...
# 82   Dial-a-ride; Dynamic routing problem; ELS; Met...
#
#                                         Index Keywords  \
# 264  Costs; Heuristic methods; Industrial managemen...
# 263  Pickups; Problem solving; Courier companies; S...
# 196                                                NaN
# 164  Dial-a-ride problem; Dynamic problem; Metaheur...
# 248  Algorithms; Dynamic programming; Fleet operati...
# 351  Algorithms; Amphibious vehicles; Branch and bo...
# 168  Adaptive memory; Central stations; Computation...
# 153  Constraint programming; Dial-a-ride problem; E...
# 181  Algorithms; Computer programming; Constraint t...
# 103  degree of dynamism; Demand responsive transpor...
# 208                                                NaN
# 34   Artificial intelligence; Computer science; Com...
# 82   Fleet operations; Transportation; Dial-a-Ride;...
#
#     Language of Original Document     Document Type            CiteArticle  \
# 264                       English           Article  cordeau&laporte(2003)
# 263                       English           Article  cordeau&laporte(2003)
# 196                       English           Article  cordeau&laporte(2003)
# 164                       English           Article  cordeau&laporte(2003)
# 248                       English           Article  cordeau&laporte(2003)
# 351                       English  Conference Paper          cordeau(2006)
# 168                       English           Article  cordeau&laporte(2003)
# 153                       English           Article  cordeau&laporte(2003)
# 181                       English           Article  cordeau&laporte(2003)
# 103                       English           Article  cordeau&laporte(2003)
# 208                       English           Article  cordeau&laporte(2003)
# 34                        English  Conference Paper  cordeau&laporte(2003)
# 82                        English  Conference Paper  cordeau&laporte(2003)
#
#                                            AllKeywords  DynamicTitle  \
# 264  Dynamic pickup and delivery problem with time ...         False
# 263  Dynamic pickup and delivery problem with time ...         False
# 196  Dial-a-ride; Dynamic mode; In-house hospital t...          True
# 164  Dial-a-ride problem; Dynamic problem; Metaheur...         False
# 248  Dial-a-ride; Dynamic; Pickup and delivery; Tim...         False
# 351  Algorithms; Amphibious vehicles; Branch and bo...         False
# 168  Health care; Real-time; Tabu search; Transport...         False
# 153  Constraint programming; Dial-a-ride problem; D...         False
# 181  Algorithms; Constraint programming; Dial-A-Rid...         False
# 103  degree of dynamism; demand responsive transpor...         False
# 208  DARP; Degree of dynamism; Dial-a-ride problem;...         False
# 34   Computational experiments; Dynamic DARP; Inser...         False
# 82   Dial-a-ride; Dynamic routing problem; ELS; Met...         False
#
#      DynamicKeywords  DynamicAbstract  DynamicAny  \
# 264             True            False        True
# 263             True            False        True
# 196             True            False        True
# 164             True            False        True
# 248             True            False        True
# 351             True            False        True
# 168             True            False        True
# 153             True            False        True
# 181             True            False        True
# 103             True            False        True
# 208             True            False        True
# 34              True            False        True
# 82              True            False        True
#
#                                Instance
# 264                Self-made, Realistic
# 263                Self-made, Realistic
# 196                     Self-made, Real
# 164  Self-made, Realistic, Dynamization
# 248                Self-made, Realistic
# 351                     Self-made, Real
# 168          Self-made, Real, Realistic
# 153         Cordeau(2006), Dynamization
# 181         Cordeau(2006), Dynamization
# 103                           Self-made
# 208                           Self-made
# 34                            Self-made
# 82                            Self-made

# %% [markdown]
# Com isso, analizamos os métodos de dinamização de cada um dos três artigos que usam deste artifício.

# %%
artigos_instancias[artigos_instancias["Instance"].str.contains("Dynamization")]
# Out:
#                                      Authors  \
# 153  Berbeglia G., Cordeau J.-F., Laporte G.
# 164     Schilde M., Doerner K.F., Hartl R.F.
# 181  Berbeglia G., Pesant G., Rousseau L.-M.
#
#                                                  Title  Year  \
# 153  A hybrid tabu search and constraint programmin...  2012
# 164  Metaheuristics for the dynamic stochastic dial...  2011
# 181  Checking the feasibility of dial-a-ride instan...  2011
#
#                           Source title  Cited by  \
# 153       INFORMS Journal on Computing      26.0
# 164  Computers and Operations Research      48.0
# 181             Transportation Science      16.0
#
#                                               Abstract  \
# 153  This paper introduces a hybrid algorithm for t...
# 164  The problem of transporting patients or elderl...
# 181  In the dial-a-ride problem (DARP), a fleet of ...
#
#                                        Author Keywords  \
# 153  Constraint programming; Dial-a-ride problem; D...
# 164  Dial-a-ride problem; Dynamic problem; Metaheur...
# 181  Algorithms; Constraint programming; Dial-A-Rid...
#
#                                         Index Keywords  \
# 153  Constraint programming; Dial-a-ride problem; E...
# 164  Dial-a-ride problem; Dynamic problem; Metaheur...
# 181  Algorithms; Computer programming; Constraint t...
#
#     Language of Original Document Document Type            CiteArticle  \
# 153                       English       Article  cordeau&laporte(2003)
# 164                       English       Article  cordeau&laporte(2003)
# 181                       English       Article  cordeau&laporte(2003)
#
#                                            AllKeywords  DynamicTitle  \
# 153  Constraint programming; Dial-a-ride problem; D...         False
# 164  Dial-a-ride problem; Dynamic problem; Metaheur...         False
# 181  Algorithms; Constraint programming; Dial-A-Rid...         False
#
#      DynamicKeywords  DynamicAbstract  DynamicAny  \
# 153             True            False        True
# 164             True            False        True
# 181             True            False        True
#
#                                Instance
# 153         Cordeau(2006), Dynamization
# 164  Self-made, Realistic, Dynamization
# 181         Cordeau(2006), Dynamization
